# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url='https://static.bc-edx.com/data/web/mars_facts/temperature.html'
browser.visit(url)
html=browser.html

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
table=soup(html,'html.parser')

# %%
# Extract all rows of data
rows=table.find_all('tr',class_='data-row')
rows
# Out:
# [<tr class="data-row">
#  <td>2</td>
#  <td>2012-08-16</td>
#  <td>10</td>
#  <td>155</td>
#  <td>6</td>
#  <td>-75.0</td>
#  <td>739.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>13</td>
#  <td>2012-08-17</td>
#  <td>11</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>24</td>
#  <td>2012-08-18</td>
#  <td>12</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>741.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>35</td>
#  <td>2012-08-19</td>
#  <td>13</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>732.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>46</td>
#  <td>2012-08-20</td>
#  <td>14</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>57</td>
#  <td>2012-08-21</td>
#  <td>15</td>
#  <td>158</td>
#  <td>6</td>
#  <td>-78.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>68</td>
#  <td>2012-08-22</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
data_dict={
    'id':[],
    'terrestrial_date':[],
    'sol':[],
    'ls':[],
    'month':[],
    'min_temp':[],
    'pressure':[],
}
# Loop through the scraped data to capture data to dict
for r in rows:
    data_list=r.find_all('td')
    data_dict['id'].append(data_list[0].text)
    data_dict['terrestrial_date'].append(data_list[1].text)
    data_dict['sol'].append(data_list[2].text)
    data_dict['ls'].append(data_list[3].text)
    data_dict['month'].append(data_list[4].text)
    data_dict['min_temp'].append(data_list[5].text)
    data_dict['pressure'].append(data_list[6].text)

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
df=pd.DataFrame(data_dict)

# %%
# Confirm DataFrame was created successfully
df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
import datetime
# Change data types for data analysis
df=df.astype({'id':'int',
             'sol':'int',
             'ls':'int',
             'month':'int',
             'min_temp':'float',
             'pressure':'float'})
df['terrestrial_date']=pd.to_datetime(df['terrestrial_date'],format='%Y-%m-%d')

# %%
# Confirm type changes were successful by examining data types again
df.dtypes
# Out:
# id                           int32
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
months=df['month'].nunique()
print(f'Numbers of months in Mars is {months} months')
# Out:
# Numbers of months in Mars is 12 months

# %%
# 2. How many Martian days' worth of data are there?
days=df['sol'].nunique()
print(f'Data consists of {sol_days} days')
# Out:
# Data consists of 1867 days

# %%
# 3. What is the average low temperature by month?
Temp_by_month_df=df.groupby(by='month',as_index=False).agg(Avg_low_temperature=('min_temp','mean'))
Temp_by_month_df.columns=['Month','Avg Low Temperature']
Temp_by_month_df
# Out:
#     Month  Avg Low Temperature
# 0       1           -77.160920
# 1       2           -79.932584
# 2       3           -83.307292
# 3       4           -82.747423
# 4       5           -79.308725
# 5       6           -75.299320
# 6       7           -72.281690
# 7       8           -68.382979
# 8       9           -69.171642
# 9      10           -71.982143
# 10     11           -71.985507
# 11     12           -74.451807

# %%
# Plot the average temperature by month
Temp_by_month_df.plot(x='Month',y='Avg Low Temperature',
                      title='Avg Low Temperature (C) by Month',
                      ylabel='Temperature (C)',
                      figsize=(10,5)
                     )
# Out:
# <AxesSubplot:title={'center':'Avg Low Temperature (C) by Month'}, xlabel='Month', ylabel='Temperature (C)'>

# %%
# Identify the coldest and hottest months in Curiosity's location
Month_Tem_df=df.groupby('month',as_index=False).agg(Average=('min_temp','mean'))
Max_Temp=Month_Tem_df.sort_values(by='Average',ascending=False)
print(f'Hotest month is month {Max_Temp.iloc[0,0]} and temperature = {Max_Temp.iloc[0,1]}')
Min_Temp=Ls_Month_Tem_df.sort_values(by='Average',ascending=True)
print(f'Coldest month is month {Min_Temp.iloc[0,0]} and temperature = {Min_Temp.iloc[0,1]}')
# Out:
# Hotest month is month 8 and temperature = -68.38297872340425
# Coldest month is month 3 and temperature = -83.30729166666667

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %%
# 4. Average pressure by Martian month
Pressure_by_month_df=df.groupby(by='month',as_index=False).agg(Avg_pressure=('pressure','mean'))
Pressure_by_month_df.columns=['Month','Avg Pressure']
Pressure_by_month_df
# Out:
#     Month  Avg Pressure
# 0       1    862.488506
# 1       2    889.455056
# 2       3    877.322917
# 3       4    806.329897
# 4       5    748.557047
# 5       6    745.054422
# 6       7    795.105634
# 7       8    873.829787
# 8       9    913.305970
# 9      10    887.312500
# 10     11    857.014493
# 11     12    842.156627

# %%
# Plot the average pressure by month
Pressure_by_month_df.plot(x='Month',y='Avg Pressure',
                      title='Avg Pressure by Month',
                      figsize=(10,5)
                     )
# Out:
# <AxesSubplot:title={'center':'Avg Pressure by Month'}, xlabel='Month'>

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
df.plot(x='terrestrial_date',y='ls',
                      title='Ls by Earth Day',
                      figsize=(15,5))
# Out:
# <AxesSubplot:title={'center':'Ls by Earth Day'}, xlabel='terrestrial_date'>

# %% [markdown]
# The distance from first peak to second peak is roughly from July-2013 to May-2015, or 669 days. A year on Mars appears to be about 669 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days. The test below will prove if the difference between 2 peak is indeed 687 when we extract the exact date of the first 2 peak

# %% [markdown]
# ### Calculate days difference in Earth day for ls = 0

# %%
# Filter Dataframe to only ls = 0
ls_0_ter=df.loc[df['ls']==0,:]
ls_0_ter
# Out:
#         id terrestrial_date   sol  ls  month  min_temp  pressure  year
# 304    320       2013-08-01   351   0      1     -75.0     853.0  2013
# 305    319       2013-08-02   352   0      1     -77.0     854.0  2013
# 925    954       2015-06-19  1019   0      1     -81.0     849.0  2015
# 926    938       2015-06-20  1020   0      1     -63.0     832.0  2015
# 1579  1606       2017-05-06  1688   0      1     -76.0     840.0  2017
# 1580  1610       2017-05-07  1689   0      1     -75.0     840.0  2017

# %%
#Put date from data table where ls = 0
date_data=[]
for d in ls_0_ter['terrestrial_date']:
    date_data.append(d)
    
days_dif=[]
for i in range(2,len(date_data)):
    days_dif.append((date_data[i]-date_data[i-2]).days)

avg_days=sum(days_dif)/len(days_dif)
print(f'By earth time, it takes {avg_days} days for Mars to circle the Sun once')
# Out:
# By earth time, it takes 687.0 days for Mars to circle the Sun once

# %% [markdown]
# ### Repeat the calculation for ls = 35 (random ls) to examine whether the result similar to ls = 0

# %%
# Filter Dataframe to only ls = 35
ls_35_ter=df.loc[df['ls']==35,:]
ls_35_ter
#Put date from data table where ls = 35
date_data=[]
for d in ls_35_ter['terrestrial_date']:
    date_data.append(d)
    
days_dif=[]
for i in range(2,len(date_data)):
    days_dif.append((date_data[i]-date_data[i-2]).days)

avg_days=sum(days_dif)/len(days_dif)
print(f'By earth time, it takes {avg_days} days for Mars to circle the Sun once')
# Out:
# By earth time, it takes 687.0 days for Mars to circle the Sun once

# %% [markdown]
# From both visualiztion and test case, we can safely conclude that 1 year on Mars is equivalent to 687 days on Earth

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
df.to_csv('Output/Mars_weather_data.csv',index=False,header=True)

# %%
browser.quit()
